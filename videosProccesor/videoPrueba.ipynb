# %%
import video

# %%
videos = video.VVideo("vid.mp4")

# %%
videos.check_video()
# Out:
# True

# %%
fps = videos.get_fps()
frame_count = videos.get_frame_count()
duration = videos.get_duration()
width = videos.get_width()
height = videos.get_height()

# %%
print('Fps:\t\t\t\t',fps,'\nNumero de frames:\t',frame_count,'\nDuracion:\t\t\t',duration,'\nAlto:\t\t\t\t',width,'\nAncho:\t\t\t\t',height)
# Out:
# Fps:				 25.0
# Numero de frames:	 3742
# Duracion:			 149.68
# Alto:				 640
# Ancho:				 360

# %%
print(videos.get_part_video(32,69,"videocorto1.mp4",3))
# Out:
# Extrayendo del cuadro 800 al 1725...
# normalized_mean_diff =  243.96816056779278
# normalized_mean_fft_diff =  132.8951824106067
# normalized_mean_diff =  347.7994446821911
# normalized_mean_fft_diff =  867.5978258990319
# normalized_mean_diff =  373.9006180963762
# normalized_mean_fft_diff =  247.52833957971652
# normalized_mean_diff =  313.5264598540146
# normalized_mean_fft_diff =  282.515544279506
# normalized_mean_diff =  271.52449474355666
# normalized_mean_fft_diff =  280.6715908661916
# normalized_mean_diff =  805.4895163829856
# normalized_mean_fft_diff =  299.9079459697114
# normalized_mean_diff =  516.7330871309993
# normalized_mean_fft_diff =  189.15894632743067
# normalized_mean_diff =  1000.0
# normalized_mean_fft_diff =  288.952567750839
# normalized_mean_diff =  86.53563743459725
# normalized_mean_fft_diff =  194.23066017034984
# normalized_mean_diff =  115.54385214133454
# normalized_mean_fft_diff =  210.7082566766533
# normalized_mean_diff =  999.9264471368127
# ...
